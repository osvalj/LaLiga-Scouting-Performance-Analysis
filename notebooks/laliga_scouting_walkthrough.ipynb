# %% [markdown]
# # LaLiga Scouting & Performance Analysis (BigQuery) — Walkthrough Notebook
# **Author / Autor:** Osval
# **Target environment / Entorno objetivo:** Google Colab + BigQuery
#
# ---
#
# ## What this is / Qué es
# **EN**
# This notebook is a narrative walkthrough of the SQL pipeline used in this project. It includes both explanations (Markdown) and executable steps (Python + BigQuery).
#
# **ES**
# Este notebook es un recorrido narrativo del pipeline SQL usado en el proyecto. Incluye explicaciones (Markdown) y pasos ejecutables (Python + BigQuery).
#
# > **Note / Nota:** GitHub renders notebooks for reading, but execution is done in Colab (or locally).

# %% [markdown]
# ## 0) Setup / Configuración
#
# **EN**
# This notebook queries BigQuery tables. You need a Google account with access to a GCP project. Depending on your setup, creating tables may require billing to be enabled.
#
# **ES**
# Este notebook consulta tablas en BigQuery. Necesitas una cuenta de Google con acceso a un proyecto de GCP. Según tu configuración, crear tablas puede requerir que la facturación esté habilitada.

# %%
# Install dependencies (Colab-friendly)
# !pip -q install google-cloud-bigquery pydata-google-auth pandas

from google.colab import auth
auth.authenticate_user()

from google.cloud import bigquery
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# ---  (project/dataset/table names) ---
PROJECT_ID = "proyecto-laliga-24-25"   # e.g. "my-gcp-project"
DATASET_ID = "Laliga_24_25"            # e.g. "laliga_scouting"
RAW_TABLE  = "LaLiga_24_25"            # e.g. "players_raw"

RAW_FQN = f"{PROJECT_ID}.{DATASET_ID}.{RAW_TABLE}"
STG_FQN = f"{PROJECT_ID}.{DATASET_ID}.stg_player_match"
MART_PLAYER_POS_FQN = f"{PROJECT_ID}.{DATASET_ID}.mart_player_season_by_position"
MART_TEAM_FQN = f"{PROJECT_ID}.{DATASET_ID}.mart_team_season"
MART_ENRICHED_FQN = f"{PROJECT_ID}.{DATASET_ID}.mart_player_season_enriched"
MART_FORM_FQN = f"{PROJECT_ID}.{DATASET_ID}.mart_player_form_last5"

client = bigquery.Client(project=PROJECT_ID)

def q(sql: str) -> pd.DataFrame:

    return client.query(sql).to_dataframe()

print("Configured RAW table:", RAW_FQN)
# Out:
# Configured RAW table: proyecto-laliga-24-25.Laliga_24_25.LaLiga_24_25

# %% [markdown]
# ## 1) Quick profiling (like `df.info()` + `df.head()`)
#
# **EN — Why**
# Before building marts, I check table scale and schema to avoid wrong assumptions.
#
# **ES — Por qué**
# Antes de construir tablas analíticas, reviso tamaño y esquema para evitar supuestos erróneos.

# %%
# 1.1 Row count
q(f"SELECT COUNT(*) AS total_rows FROM `{RAW_FQN}`")
# Out:
#    total_rows
# 0        4658

# %%
# 1.2 Schema inspection (names + types)
q(f'''
SELECT column_name, data_type, is_nullable
FROM `{PROJECT_ID}.{DATASET_ID}.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = '{RAW_TABLE}'
ORDER BY ordinal_position
''')
# Out:
#      column_name data_type is_nullable
# 0        fecha_p      DATE         YES
# 1        Jugador    STRING         YES
# 2         Equipo    STRING         YES
# 3           Pais    STRING         YES
# 4       Posicion    STRING         YES
# 5           edad    STRING         YES
# 6        minutos     INT64         YES
# 7          goles     INT64         YES
# 8    asistencias     INT64         YES
# 9          Tiros     INT64         YES
# 10  Tiros_puerta     INT64         YES
# 11     Amarillas     INT64         YES
# 12         rojas     INT64         YES
# 13        toques     INT64         YES
# 14       regates     INT64         YES
# 15   regates_int     INT64         YES
# 16    regates_ok     INT64         YES
# 17      entradas     INT64         YES
# 18      blocajes     INT64         YES
# 19        crea_t     INT64         YES
# 20        crea_g     INT64         YES
# 21    pase_compl     INT64         YES
# 22      pase_int     INT64         YES
# 23    pases_prog     INT64         YES
# 24       conducc     INT64         YES
# 25  conducc_prog     INT64         YES
# 26            xg   FLOAT64         YES
# 27          npxg   FLOAT64         YES
# 28           xag   FLOAT64         YES
# 29           pen     INT64         YES
# 30        pen_oj     INT64         YES

# %%
# 1.3 Sample rows
q(f"SELECT * FROM `{RAW_FQN}` LIMIT 10")
# Out:
#       fecha_p              Jugador           Equipo Pais Posicion    edad  \
# 0  2024-09-29      Abde Ezzalzouli       Real Betis  MAR       LW  22-287
# 1  2024-09-13      Abde Ezzalzouli       Real Betis  MAR       LW  22-271
# 2  2024-08-17           Aimar Oroz          Osasuna  ESP       LW  22-264
# 3  2024-09-30           Alex Baena       Villarreal  ESP    LM,FW  23-072
# 4  2024-10-20    Alexander Sørloth  Atlético Madrid  NOR       FW  28-320
# 5  2024-11-04  Anastasios Douvikas       Celta Vigo  GRE       FW  25-094
# 6  2024-11-02         Ante Budimir          Osasuna  CRO       FW  33-103
# 7  2024-09-28         Ante Budimir          Osasuna  CRO       FW  33-068
# 8  2024-09-15    Antoine Griezmann  Atlético Madrid  FRA    FW,CM  33-178
# 9  2024-09-14          Ayoze Pérez       Villarreal  ESP       FW  31-047
#
#    minutos  goles  asistencias  Tiros  Tiros_puerta  Amarillas  rojas  toques  \
# 0       87      0            0      2             2          0      0      47
# 1       90      1            0      4             4          0      0      71
# 2       89      0            0      4             1          0      0      58
# 3       45      1            1      2             1          0      0      40
# 4       90      2            0      7             3          0      0      38
# 5       66      1            0      3             2          1      0      25
# 6       84      1            0      7             0          0      0      34
# 7       76      2            0      2             1          0      0      22
# 8       75      1            0      2             1          0      0      61
# 9       90      1            0      4             1          0      0      35
#
#    regates  regates_int  regates_ok  entradas  blocajes  crea_t  crea_g  \
# 0        0            6           0         0         1       9       0
# 1        0            4           1         0         0       2       1
# 2        2            6           2         2         2       4       0
# 3        0            1           0         2         0       6       1
# 4        1            2           2         0         0       4       0
# 5        1            1           0         0         0       1       1
# 6        0            0           0         0         2       5       1
# 7        0            1           0         0         2       1       1
# 8        1            1           1         1         2       3       1
# 9        0            3           2         0         0       6       0
#
#    pase_compl  pase_int  pases_prog  conducc  conducc_prog   xg  npxg  xag  \
# 0          19        31           3       32             5  1.2   0.4  0.4
# 1          39        55           6       40             9  1.2   1.2  0.0
# 2          38        42           6       30             1  0.7   0.7  0.1
# 3          23        31           6       21             1  1.1   0.3  0.6
# 4          15        20           1       18             3  2.0   2.0  0.0
# 5           8        15           0       11             0  1.3   1.3  0.0
# 6          10        17           6       18             1  1.4   0.7  0.2
# 7           9        11           0       13             1  1.0   0.2  0.0
# 8          33        48           6       31             3  0.7   0.7  0.0
# 9          18        22           3       28             5  0.7   0.7  0.3
#
#    pen  pen_oj
# 0    1       0
# 1    0       0
# 2    0       0
# 3    1       0
# 4    0       0
# 5    0       0
# 6    1       1
# 7    1       1
# 8    0       0
# 9    0       0

# %% [markdown]
# ## 2) Staging layer: clean + typed table (`stg_player_match`)
#
# **EN — Why**
# Raw CSV/JSON often stores numbers as strings and may contain whitespace or malformed values.
# This project uses defensive SQL: `SAFE_CAST`, `TRIM`, `NULLIF`, `SAFE_DIVIDE`.
#
# **ES — Por qué**
# Los CSV/JSON suelen traer números como texto y valores inconsistentes.
# Este proyecto usa SQL defensivo: `SAFE_CAST`, `TRIM`, `NULLIF`, `SAFE_DIVIDE`.
#
# **Grain / Grano**
# One row = player + team + date. Player names repeat across dates by design.
# Una fila = jugador + equipo + fecha. Los nombres se repiten por diseño.

# %%
# Create/replace staging table (adjust column names if your raw schema differs)
stg_sql = f'''
CREATE OR REPLACE TABLE `{STG_FQN}` AS
SELECT
  SAFE_CAST(`fecha_p` AS DATE) AS match_date,
  TRIM(CAST(`Jugador` AS STRING)) AS player_name,
  TRIM(CAST(`Equipo` AS STRING)) AS team,
  TRIM(CAST(`Pais` AS STRING)) AS nation,
  TRIM(CAST(`Posicion` AS STRING)) AS position,

  SAFE_CAST(`minutos` AS INT64) AS minutes,
  SAFE_CAST(`goles` AS INT64) AS goals,
  SAFE_CAST(`asistencias` AS INT64) AS assists,

  SAFE_CAST(`Tiros` AS INT64) AS shots_total,
  SAFE_CAST(`Tiros_puerta` AS INT64) AS shots_on_target,

  SAFE_CAST(`xg` AS FLOAT64) AS xg,
  SAFE_CAST(`xAG` AS FLOAT64) AS xag,

  TO_HEX(MD5(CONCAT(
    CAST(SAFE_CAST(`fecha_p` AS DATE) AS STRING), '|',
    TRIM(CAST(`Equipo` AS STRING)), '|',
    TRIM(CAST(`Jugador` AS STRING))
  ))) AS player_team_date_key
FROM `{RAW_FQN}`
WHERE `Jugador` IS NOT NULL
  AND `Equipo` IS NOT NULL
  AND `fecha_p` IS NOT NULL
'''
client.query(stg_sql).result()
print("Created:", STG_FQN)
# Out:
# Created: proyecto-laliga-24-25.Laliga_24_25.stg_player_match

# %% [markdown]
# ## 3) Data Quality checks (nulls, duplicates)
#
# **EN — Why**
# Quality is not assumed; it is measured. These checks validate the staging assumptions.
#
# **ES — Por qué**
# La calidad no se asume; se mide. Estos checks validan los supuestos del staging.

# %%
# 3.1 Null counts on critical fields
q(f'''
SELECT
  COUNT(*) AS rows_total,
  COUNTIF(match_date IS NULL) AS null_match_date,
  COUNTIF(player_name IS NULL OR player_name = '') AS null_player_name,
  COUNTIF(team IS NULL OR team = '') AS null_team,
  COUNTIF(position IS NULL OR position = '') AS null_position
FROM `{STG_FQN}`
''')
# Out:
#    rows_total  null_match_date  null_player_name  null_team  null_position
# 0        4658                0                 0          0              0

# %%
# 3.2 Duplicates by grain key (true duplicates)
q(f'''
SELECT player_team_date_key, COUNT(*) AS cnt
FROM `{STG_FQN}`
GROUP BY 1
HAVING COUNT(*) > 1
ORDER BY cnt DESC
LIMIT 50
''')
# Out:
# Empty DataFrame
# Columns: [player_team_date_key, cnt]
# Index: []

# %% [markdown]
# ## 4) Core mart: player season by position
#
# **EN — Why**
# Scouting is role-dependent. We aggregate by player + team + nation + position.
# Per-90 metrics make players comparable despite different minutes.
#
# **ES — Por qué**
# El scouting depende del rol. Agregamos por jugador + equipo + país + posición.
# Las métricas por 90 permiten comparar jugadores con minutos distintos.

# %%
mart_player_sql = f'''
CREATE OR REPLACE TABLE `{MART_PLAYER_POS_FQN}` AS
SELECT
  player_name,
  team,
  nation,
  position,

  COUNT(*) AS appearances_rows,
  COUNTIF(minutes > 0) AS matches_played,
  SUM(minutes) AS minutes,

  SUM(goals) AS goals,
  SUM(assists) AS assists,
  SUM(xg) AS xg,
  SUM(xag) AS xag,
  SUM(shots_total) AS shots_total,
  SUM(shots_on_target) AS shots_on_target,

  ROUND(SUM(goals) * 90.0 / NULLIF(SUM(minutes), 0), 3) AS goals_per90,
  ROUND(SUM(assists) * 90.0 / NULLIF(SUM(minutes), 0), 3) AS assists_per90,
  ROUND(SUM(xg) * 90.0 / NULLIF(SUM(minutes), 0), 3) AS xg_per90,
  ROUND(SUM(xag) * 90.0 / NULLIF(SUM(minutes), 0), 3) AS xag_per90,

  ROUND(SAFE_DIVIDE(SUM(goals), NULLIF(SUM(shots_on_target), 0)), 3) AS goals_per_shot_on_target
FROM `{STG_FQN}`
GROUP BY player_name, team, nation, position
'''
client.query(mart_player_sql).result()
print("Created:", MART_PLAYER_POS_FQN)
# Out:
# Created: proyecto-laliga-24-25.Laliga_24_25.mart_player_season_by_position

# %%
# Top players by attacking threat (xG+xAG per90) with minutes threshold
q(f'''
SELECT
  position,
  player_name,
  team,
  minutes,
  xg_per90,
  xag_per90,
  ROUND(xg_per90 + xag_per90, 3) AS threat_per90
FROM `{MART_PLAYER_POS_FQN}`
WHERE minutes >= 900
ORDER BY threat_per90 DESC
LIMIT 25
''')
# Out:
#    position         player_name             team  minutes  xg_per90  \
# 0        FW  Robert Lewandowski        Barcelona     1248     1.017
# 1        FW       Kylian Mbappé      Real Madrid     1019     0.821
# 2        RW        Lamine Yamal        Barcelona     1033     0.357
# 3        FW        Ante Budimir          Osasuna     1103     0.530
# 4        FW        Vedat Muriqi         Mallorca      901     0.390
# 5        FW        Isaac Romero          Sevilla      978     0.193
# 6        LB       Sergi Cardona       Villarreal     1232     0.124
# 7        CM       Daniel Parejo       Villarreal      924     0.185
# 8        CB        Nayef Aguerd    Real Sociedad      919     0.196
# 9        RB        Pablo Maffeo         Mallorca      916     0.020
# 10       CM                Koke  Atlético Madrid     1006     0.081
# 11       LB     Alejandro Balde        Barcelona      931     0.019
# 12       LB        Johan Mojica         Mallorca     1159     0.031
# 13       RB        Jules Koundé        Barcelona      985     0.027
# 14       RB     Nahuel Tenaglia           Alavés      931     0.048
# 15       CB         Pau Cubarsí        Barcelona     1291     0.049
# 16       CB       César Tárrega         Valencia      990     0.109
# 17       CB      Antonio Raillo         Mallorca     1420     0.051
# 18       CB      Iñigo Martínez        Barcelona     1330     0.020
# 19       LB          Diego Rico           Getafe     1167     0.015
# 20       LB      Yuri Berchiche    Athletic Club      912     0.030
# 21       RB         Jesús Areso          Osasuna     1152     0.000
# 22       CB        Éder Militão      Real Madrid      938     0.048
# 23       CB     Antonio Rüdiger      Real Madrid     1260     0.079
# 24       CB           Loïc Bade          Sevilla      921     0.020
#
#     xag_per90  threat_per90
# 0       0.166         1.183
# 1       0.071         0.892
# 2       0.505         0.862
# 3       0.049         0.579
# 4       0.060         0.450
# 5       0.110         0.303
# 6       0.124         0.248
# 7       0.029         0.214
# 8       0.010         0.206
# 9       0.177         0.197
# 10      0.081         0.162
# 11      0.135         0.154
# 12      0.116         0.147
# 13      0.091         0.118
# 14      0.068         0.116
# 15      0.063         0.112
# 16      0.000         0.109
# 17      0.057         0.108
# 18      0.081         0.101
# 19      0.077         0.092
# 20      0.059         0.089
# 21      0.086         0.086
# 22      0.038         0.086
# 23      0.007         0.086
# 24      0.059         0.079

# %% [markdown]
# ## 5) Team context (join example)
#
# **EN — Why**
# Team context helps interpret individual stats (dependency, style effects).
#
# **ES — Por qué**
# El contexto del equipo ayuda a interpretar estadísticas individuales (dependencia, efectos de estilo).

# %%
team_sql = f'''
CREATE OR REPLACE TABLE `{MART_TEAM_FQN}` AS
SELECT
  team,
  SUM(minutes) AS team_minutes,
  SUM(goals) AS team_goals,
  SUM(xg) AS team_xg,
  ROUND(SUM(goals) * 90.0 / NULLIF(SUM(minutes), 0), 3) AS team_goals_per90
FROM `{STG_FQN}`
GROUP BY team
'''
client.query(team_sql).result()
print("Created:", MART_TEAM_FQN)
# Out:
# Created: proyecto-laliga-24-25.Laliga_24_25.mart_team_season

# %%
enrich_sql = f'''
CREATE OR REPLACE TABLE `{MART_ENRICHED_FQN}` AS
SELECT
  p.*,
  t.team_goals_per90,
  ROUND(SAFE_DIVIDE(p.goals, NULLIF(t.team_goals, 0)), 4) AS share_of_team_goals
FROM `{MART_PLAYER_POS_FQN}` p
LEFT JOIN `{MART_TEAM_FQN}` t
USING (team)
'''
client.query(enrich_sql).result()
print("Created:", MART_ENRICHED_FQN)
# Out:
# Created: proyecto-laliga-24-25.Laliga_24_25.mart_player_season_enriched

# %%
# Players with high share of team goals (minimum minutes)
q(f'''
SELECT
  player_name, team, position, minutes, goals, team_goals_per90, share_of_team_goals
FROM `{MART_ENRICHED_FQN}`
WHERE minutes >= 900
ORDER BY share_of_team_goals DESC
LIMIT 25
''')
# Out:
#            player_name             team position  minutes  goals  \
# 0         Ante Budimir          Osasuna       FW     1103      9
# 1   Robert Lewandowski        Barcelona       FW     1248     15
# 2        Kylian Mbappé      Real Madrid       FW     1019      7
# 3         Vedat Muriqi         Mallorca       FW      901      3
# 4        César Tárrega         Valencia       CB      990      2
# 5          Abdul Mumin   Rayo Vallecano       CB      993      1
# 6        Daniel Vivian    Athletic Club       CB     1045      2
# 7         Lamine Yamal        Barcelona       RW     1033      4
# 8        Daniel Parejo       Villarreal       CM      924      2
# 9      Marash Kumbulla         Espanyol       CB     1012      1
# 10               Sergi          Leganés       CB     1302      1
# 11        Johan Mojica         Mallorca       LB     1159      1
# 12      Antonio Raillo         Mallorca       CB     1420      1
# 13     Nahuel Tenaglia           Alavés       RB      931      1
# 14         Enzo Boyomo          Osasuna       CB     1080      1
# 15       Carl Starfelt       Celta Vigo       CB     1096      1
# 16       Sergi Cardona       Villarreal       LB     1232      1
# 17         Logan Costa       Villarreal       CB      916      1
# 18                Koke  Atlético Madrid       CM     1006      1
# 19        Éder Militão      Real Madrid       CB      938      1
# 20        Jules Koundé        Barcelona       RB      985      1
# 21     Alejandro Balde        Barcelona       LB      931      0
# 22           Loïc Bade          Sevilla       CB      921      0
# 23        Kiko Femenía       Villarreal       RB     1103      0
# 24         David Soria           Getafe       GK     1350      0
#
#     team_goals_per90  share_of_team_goals
# 0              0.109               0.5000
# 1              0.273               0.3125
# 2              0.188               0.2258
# 3              0.086               0.2000
# 4              0.091               0.1538
# 5              0.071               0.1000
# 6              0.137               0.0833
# 7              0.273               0.0833
# 8              0.163               0.0800
# 9              0.091               0.0714
# 10             0.085               0.0714
# 11             0.086               0.0667
# 12             0.086               0.0667
# 13             0.097               0.0625
# 14             0.109               0.0556
# 15             0.134               0.0455
# 16             0.163               0.0400
# 17             0.163               0.0400
# 18             0.158               0.0385
# 19             0.188               0.0323
# 20             0.273               0.0208
# 21             0.273               0.0000
# 22             0.067               0.0000
# 23             0.163               0.0000
# 24             0.061               0.0000

# %% [markdown]
# ## 6) Recent form (window functions)
#
# **EN — Why**
# Season totals hide short-term dynamics. Rolling windows approximate recent form (last 5 match dates).
#
# **ES — Por qué**
# Los totales esconden dinámicas a corto plazo. Ventanas móviles aproximan la forma reciente (últimas 5 fechas).

# %%
form_sql = f'''
CREATE OR REPLACE TABLE `{MART_FORM_FQN}` AS
WITH base AS (
  SELECT
    player_name,
    team,
    match_date,
    minutes,
    goals,
    xg,
    SUM(goals) OVER (PARTITION BY player_name, team ORDER BY match_date ROWS BETWEEN 4 PRECEDING AND CURRENT ROW) AS goals_last5,
    SUM(xg) OVER (PARTITION BY player_name, team ORDER BY match_date ROWS BETWEEN 4 PRECEDING AND CURRENT ROW) AS xg_last5,
    SUM(minutes) OVER (PARTITION BY player_name, team ORDER BY match_date ROWS BETWEEN 4 PRECEDING AND CURRENT ROW) AS minutes_last5
  FROM `{STG_FQN}`
)
SELECT
  player_name,
  team,
  match_date,
  goals_last5,
  xg_last5,
  minutes_last5,
  ROUND(goals_last5 * 90.0 / NULLIF(minutes_last5,0), 3) AS goals_per90_last5,
  ROUND(xg_last5 * 90.0 / NULLIF(minutes_last5,0), 3) AS xg_per90_last5
FROM base
'''
client.query(form_sql).result()
print("Created:", MART_FORM_FQN)
# Out:
# Created: proyecto-laliga-24-25.Laliga_24_25.mart_player_form_last5

# %%
# Example: players trending up in last 5 (minimum rolling minutes)
q(f'''
SELECT
  player_name, team, match_date, minutes_last5, goals_per90_last5, xg_per90_last5
FROM `{MART_FORM_FQN}`
WHERE minutes_last5 >= 300
ORDER BY goals_per90_last5 DESC
LIMIT 25
''')
# Out:
#            player_name         team  match_date  minutes_last5  \
# 0   Robert Lewandowski    Barcelona  2024-10-20            390
# 1   Robert Lewandowski    Barcelona  2024-10-26            390
# 2   Robert Lewandowski    Barcelona  2024-11-03            404
# 3          Ayoze Pérez   Villarreal  2024-10-26            350
# 4   Robert Lewandowski    Barcelona  2024-11-10            425
# 5   Robert Lewandowski    Barcelona  2024-10-06            393
# 6          Ayoze Pérez   Villarreal  2024-11-09            358
# 7     Giovani Lo Celso   Real Betis  2024-09-29            368
# 8          Ayoze Pérez   Villarreal  2024-09-26            374
# 9             Raphinha    Barcelona  2024-09-28            392
# 10         Ayoze Pérez   Villarreal  2024-09-22            327
# 11       Kylian Mbappé  Real Madrid  2024-10-05            411
# 12        Ante Budimir      Osasuna  2024-12-02            418
# 13     Vinicius Júnior  Real Madrid  2024-11-09            418
# 14     Vinicius Júnior  Real Madrid  2024-11-24            422
# 15  Robert Lewandowski    Barcelona  2024-11-23            423
# 16  Robert Lewandowski    Barcelona  2024-08-31            342
# 17    Giovani Lo Celso   Real Betis  2024-10-06            428
# 18        Ante Budimir      Osasuna  2024-11-02            428
# 19       Kylian Mbappé  Real Madrid  2024-09-24            431
# 20            Raphinha    Barcelona  2024-12-03            440
# 21        Ante Budimir      Osasuna  2024-10-19            359
# 22            Raphinha    Barcelona  2024-09-22            450
# 23            Raphinha    Barcelona  2024-09-25            450
# 24        Ante Budimir      Osasuna  2024-10-27            372
#
#     goals_per90_last5  xg_per90_last5
# 0               1.846           1.638
# 1               1.846           1.431
# 2               1.559           1.248
# 3               1.543           0.694
# 4               1.482           1.101
# 5               1.374           1.260
# 6               1.257           0.654
# 7               1.223           0.514
# 8               1.203           0.505
# 9               1.148           0.941
# 10              1.101           0.495
# 11              1.095           1.139
# 12              1.077           0.754
# 13              1.077           0.646
# 14              1.066           0.640
# 15              1.064           0.809
# 16              1.053           1.105
# 17              1.051           0.463
# 18              1.051           0.799
# 19              1.044           1.169
# 20              1.023           0.798
# 21              1.003           0.652
# 22              1.000           0.860
# 23              1.000           0.880
# 24              0.968           0.605
